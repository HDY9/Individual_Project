# %%
# !pip install xlrd==2.0.1
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import pandas as pd
import csv
import numpy as np

# %%
CCTV_Seoul = pd.read_csv('서울시CCTV설치운영현황(자치구)_년도별_211231기준.csv', encoding='cp949', header=1)
CCTV_Seoul.head()
# Out:
#     구분      총계 2012년 이전  2012년  2013년  2014년  2015년  2016년   2017년   2018년  \
# 0    계  83,557    4,812  1,851  3,434  4,295  6,840  8,708  11,572  10,627
# 1  종로구   1,715      815    NaN    NaN    195    150      0     261      85
# 2  중 구   2,447       16    114     87     77    236    240     372     386
# 3  용산구   2,611       34     71    234    125    221    298     351     125
# 4  성동구   3,829      163    144    208    107    325    255     967     415
#
#     2019년   2020년  2021년
# 0  12,267  11,247  7,904
# 1       9     200      0
# 2     155     361    403
# 3     307     617    228
# 4     490     472    283

# %%
CCTV_Seoul = CCTV_Seoul.drop(0, axis=0)

# %%
CCTV_Seoul.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 1 to 25
# Data columns (total 13 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   구분        25 non-null     object
#  1   총계        25 non-null     object
#  2   2012년 이전  25 non-null     object
#  3   2012년     24 non-null     object
#  4   2013년     24 non-null     object
#  5   2014년     25 non-null     object
#  6   2015년     25 non-null     object
#  7   2016년     25 non-null     object
#  8   2017년     25 non-null     object
#  9   2018년     25 non-null     object
#  10  2019년     25 non-null     object
#  11  2020년     25 non-null     object
#  12  2021년     25 non-null     object
# dtypes: object(13)
# memory usage: 2.7+ KB

# %%
CCTV_Seoul.sort_values(by='총계', ascending=True)
# Out:
#       구분     총계 2012년 이전 2012년 2013년 2014년 2015년 2016년 2017년 2018년 2019년  \
# 1    종로구  1,715      815   NaN   NaN   195   150     0   261    85     9
# 10   도봉구  1,930      128    22     2   145   172   123   129   222   210
# 20   동작구  2,306       41    24    25   503   128   253   271   300   322
# 18   금천구  2,411        0     0   174    80   361   133   196   539   367
# 2    중 구  2,447       16   114    87    77   236   240   372   386   155
# 11   노원구  2,492        0    87   164    77   514   331   175   216   320
# 14   마포구  2,496       23    19    40   112   185   478   365   373   494
# 3    용산구  2,611       34    71   234   125   221   298   351   125   307
# 6   동대문구  2,628        4     0    14    16   115   804   814   201   218
# 16   강서구  2,744       54   122   104   202   199   168   506   259   457
# 25   강동구  2,809      268    27   227    49   154   202   273   377   356
# 24   송파구  2,897       40    59    90    85   214   176   241   541  1073
# ...

# %%
CCTV_Seoul.sort_values(by='총계', ascending=True).head(5)
# Out:
#      구분     총계 2012년 이전 2012년 2013년 2014년 2015년 2016년 2017년 2018년 2019년 2020년  \
# 1   종로구  1,715      815   NaN   NaN   195   150     0   261    85     9   200
# 10  도봉구  1,930      128    22     2   145   172   123   129   222   210   184
# 20  동작구  2,306       41    24    25   503   128   253   271   300   322   419
# 18  금천구  2,411        0     0   174    80   361   133   196   539   367   513
# 2   중 구  2,447       16   114    87    77   236   240   372   386   155   361
#
#    2021년
# 1      0
# 10   593
# 20    20
# 18    48
# 2    403

# %%
CCTV_Seoul.sort_values(by='총계', ascending=False).head(5)
# Out:
#      구분     총계 2012년 이전 2012년 2013년 2014년 2015년 2016년 2017년 2018년 2019년 2020년  \
# 23  강남구  6,871       69    67    66   580   830  1293   988   745   791   926
# 21  관악구  5,149      440    84   431   439   609   622   688   674   595   331
# 17  구로구  4,608      852   216   349   187   268   326   540   488   434   415
# 8   성북구  4,602       81    78   170   229   322   594   890   867   714   253
# 12  은평구  4,131       14     3    44   332   329   555   403   635  1057   288
#
#    2021년
# 23   516
# 21   236
# 17   533
# 8    404
# 12   471

# %%
CCTV_Seoul.replace(np.nan, '0', inplace=True)

# %%
CCTV_Seoul['총계']= CCTV_Seoul['총계'].str.replace(',','')
CCTV_Seoul['총계']
# Out:
# 1     1715
# 2     2447
# 3     2611
# 4     3829
# 5     3211
# 6     2628
# 7     3737
# 8     4602
# 9     3090
# 10    1930
# 11    2492
# 12    4131
# 13    3055
# 14    2496
# 15    3650
# 16    2744
# 17    4608
# 18    2411
# 19    4056
# 20    2306
# 21    5149
# 22    4082
# 23    6871
# 24    2897
# 25    2809
# Name: 총계, dtype: object

# %%
CCTV_Seoul['총계']=list(map(lambda x: int(x),CCTV_Seoul['총계']))
CCTV_Seoul['총계']
# Out:
# 1     1715
# 2     2447
# 3     2611
# 4     3829
# 5     3211
# 6     2628
# 7     3737
# 8     4602
# 9     3090
# 10    1930
# 11    2492
# 12    4131
# 13    3055
# 14    2496
# 15    3650
# 16    2744
# 17    4608
# 18    2411
# 19    4056
# 20    2306
# 21    5149
# 22    4082
# 23    6871
# 24    2897
# 25    2809
# Name: 총계, dtype: int64

# %%
CCTV_Seoul = CCTV_Seoul.astype({'2012년':'int','2013년':'int','2014년':'int','2015년':'int','2016년':'int','2017년':'int','2018년':'int','2019년':'int','2020년':'int','2021년':'int'})

# %%
CCTV_Seoul = CCTV_Seoul.astype({'2012년 이전':'int'})

# %%
CCTV_Seoul.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 1 to 25
# Data columns (total 13 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   구분        25 non-null     object
#  1   총계        25 non-null     int64
#  2   2012년 이전  25 non-null     int32
#  3   2012년     25 non-null     int32
#  4   2013년     25 non-null     int32
#  5   2014년     25 non-null     int32
#  6   2015년     25 non-null     int32
#  7   2016년     25 non-null     int32
#  8   2017년     25 non-null     int32
#  9   2018년     25 non-null     int32
#  10  2019년     25 non-null     int32
#  11  2020년     25 non-null     int32
#  12  2021년     25 non-null     int32
# dtypes: int32(11), int64(1), object(1)
# memory usage: 1.6+ KB

# %%
CCTV_Seoul_copy = CCTV_Seoul.drop([11,18], axis=0)

# %%
CCTV_Seoul_copy['최근증가율'] = (CCTV_Seoul_copy['2021년']+CCTV_Seoul_copy['2020년']+CCTV_Seoul_copy['2019년']+CCTV_Seoul_copy['2018년']+CCTV_Seoul_copy['2017년']+CCTV_Seoul_copy['2016년']+\
                       CCTV_Seoul_copy['2015년']+CCTV_Seoul_copy['2014년']+CCTV_Seoul_copy['2013년']+CCTV_Seoul_copy['2012년']) / CCTV_Seoul_copy['2012년 이전'] *100
CCTV_Seoul_copy.sort_values(by='최근증가율', ascending=False).head(5)
# Out:
#       구분    총계  2012년 이전  2012년  2013년  2014년  2015년  2016년  2017년  2018년  \
# 6   동대문구  2628         4      0     14     16    115    804    814    201
# 22   서초구  4082         8     73     79     70    562    504   1041    417
# 9    강북구  3090         8      0     22     61    124    251     29    391
# 12   은평구  4131        14      3     44    332    329    555    403    635
# 2    중 구  2447        16    114     87     77    236    240    372    386
#
#     2019년  2020년  2021년         최근증가율
# 6     218    223    219  65600.000000
# 22    339    433    556  50925.000000
# 9    1078    656    470  38525.000000
# 12   1057    288    471  29407.142857
# 2     155    361    403  15193.750000

# %%
CCTV_Seoul = CCTV_Seoul_copy.sort_values(by='최근증가율', ascending=False)

# %%
pop_Seoul = pd.read_excel('pop_Seoul.xls')
pop_Seoul.head()
# Out:
#          기간  자치구       세대       인구     인구.1     인구.2     인구.3     인구.4  \
# 0        기간  자치구       세대       합계       합계       합계      한국인      한국인
# 1        기간  자치구       세대        계       남자       여자        계       남자
# 2  2022.1/4   합계  4451444  9732617  4716704  5015913  9506778  4613910
# 3  2022.1/4  종로구    73766   153684    74018    79666   144275    69911
# 4  2022.1/4   중구    63767   131450    63869    67581   122173    59448
#
#       인구.5    인구.6    인구.7    인구.8  세대당인구  65세이상고령자
# 0      한국인   등록외국인   등록외국인   등록외국인  세대당인구  65세이상고령자
# 1       여자       계      남자      여자  세대당인구  65세이상고령자
# 2  4892868  225839  102794  123045   2.14   1628980
# 3    74364    9409    4107    5302   1.96     28064
# 4    62725    9277    4421    4856   1.92     24742

# %%
pop_Seoul = pd.read_excel('pop_Seoul.xls',
                          header = 2,
                          usecols = 'B,D,G,J,N')
pop_Seoul.head()
# Out:
#    자치구        계      계.1     계.2  65세이상고령자
# 0   합계  9732617  9506778  225839   1628980
# 1  종로구   153684   144275    9409     28064
# 2   중구   131450   122173    9277     24742
# 3  용산구   236518   222169   14349     39461
# 4  성동구   291609   285073    6536     46896

# %%
pop_Seoul.rename(columns={pop_Seoul.columns[0] : '구별',
                          pop_Seoul.columns[1] : '인구수',
                          pop_Seoul.columns[2] : '한국인',
                          pop_Seoul.columns[3] : '외국인',
                          pop_Seoul.columns[4] : '고령자'}, inplace=True)
pop_Seoul.head()
# Out:
#     구별      인구수      한국인     외국인      고령자
# 0   합계  9732617  9506778  225839  1628980
# 1  종로구   153684   144275    9409    28064
# 2   중구   131450   122173    9277    24742
# 3  용산구   236518   222169   14349    39461
# 4  성동구   291609   285073    6536    46896

# %%
pop_Seoul.drop(0, axis=0, inplace=True)
pop_Seoul.head()
# Out:
#     구별     인구수     한국인    외국인    고령자
# 1  종로구  153684  144275   9409  28064
# 2   중구  131450  122173   9277  24742
# 3  용산구  236518  222169  14349  39461
# 4  성동구  291609  285073   6536  46896
# 5  광진구  353110  340707  12403  52604

# %%
pop_Seoul['구별'].unique()
# Out:
# array(['종로구', '중구', '용산구', '성동구', '광진구', '동대문구', '중랑구', '성북구', '강북구',
#        '도봉구', '노원구', '은평구', '서대문구', '마포구', '양천구', '강서구', '구로구', '금천구',
#        '영등포구', '동작구', '관악구', '서초구', '강남구', '송파구', '강동구'], dtype=object)

# %%
pop_Seoul[pop_Seoul['구별'].isnull()]
# Out:
# Empty DataFrame
# Columns: [구별, 인구수, 한국인, 외국인, 고령자]
# Index: []

# %%
pop_Seoul['외국인비율'] = pop_Seoul['외국인'] / pop_Seoul['인구수'] * 100
pop_Seoul['고령자비율'] = pop_Seoul['고령자'] / pop_Seoul['인구수'] * 100
pop_Seoul.head()
# Out:
#     구별     인구수     한국인    외국인    고령자     외국인비율      고령자비율
# 1  종로구  153684  144275   9409  28064  6.122303  18.260847
# 2   중구  131450  122173   9277  24742  7.057436  18.822366
# 3  용산구  236518  222169  14349  39461  6.066769  16.684142
# 4  성동구  291609  285073   6536  46896  2.241357  16.081808
# 5  광진구  353110  340707  12403  52604  3.512503  14.897341

# %%
pop_Seoul.sort_values(by='인구수', ascending=False).head(5)
# Out:
#      구별     인구수     한국인    외국인    고령자     외국인비율      고령자비율
# 24  송파구  668261  662607   5654  99854  0.846077  14.942365
# 16  강서구  578426  573046   5380  93924  0.930110  16.237859
# 23  강남구  537338  532577   4761  79575  0.886034  14.809115
# 11  노원구  514445  510486   3959  89426  0.769567  17.383005
# 21  관악구  500336  486375  13961  80686  2.790325  16.126363

# %%
pop_Seoul.sort_values(by='외국인', ascending=False).head(5)
# Out:
#       구별     인구수     한국인    외국인    고령자     외국인비율      고령자비율
# 17   구로구  419984  396017  23967  73864  5.706646  17.587337
# 19  영등포구  400241  376740  23501  63547  5.871712  15.877184
# 6   동대문구  352592  337982  14610  62963  4.143599  17.857183
# 3    용산구  236518  222169  14349  39461  6.066769  16.684142
# 21   관악구  500336  486375  13961  80686  2.790325  16.126363

# %%
pop_Seoul.sort_values(by='외국인비율', ascending=False).head(5)
# Out:
#       구별     인구수     한국인    외국인    고령자     외국인비율      고령자비율
# 2     중구  131450  122173   9277  24742  7.057436  18.822366
# 1    종로구  153684  144275   9409  28064  6.122303  18.260847
# 3    용산구  236518  222169  14349  39461  6.066769  16.684142
# 19  영등포구  400241  376740  23501  63547  5.871712  15.877184
# 17   구로구  419984  396017  23967  73864  5.706646  17.587337

# %%
pop_Seoul.sort_values(by='고령자', ascending=False).head(5)
# Out:
#      구별     인구수     한국인    외국인    고령자     외국인비율      고령자비율
# 24  송파구  668261  662607   5654  99854  0.846077  14.942365
# 16  강서구  578426  573046   5380  93924  0.930110  16.237859
# 11  노원구  514445  510486   3959  89426  0.769567  17.383005
# 12  은평구  476013  472259   3754  88418  0.788634  18.574703
# 21  관악구  500336  486375  13961  80686  2.790325  16.126363

# %%
pop_Seoul.sort_values(by='고령자비율', ascending=False).head(5)
# Out:
#      구별     인구수     한국인   외국인    고령자     외국인비율      고령자비율
# 9   강북구  300824  297384  3440  64961  1.143526  21.594354
# 10  도봉구  318100  316098  2002  65122  0.629362  20.472179
# 2    중구  131450  122173  9277  24742  7.057436  18.822366
# 12  은평구  476013  472259  3754  88418  0.788634  18.574703
# 7   중랑구  393600  389043  4557  72851  1.157774  18.508892

# %%
CCTV_Seoul.head()
# Out:
#       구분    총계  2012년 이전  2012년  2013년  2014년  2015년  2016년  2017년  2018년  \
# 6   동대문구  2628         4      0     14     16    115    804    814    201
# 22   서초구  4082         8     73     79     70    562    504   1041    417
# 9    강북구  3090         8      0     22     61    124    251     29    391
# 12   은평구  4131        14      3     44    332    329    555    403    635
# 2    중 구  2447        16    114     87     77    236    240    372    386
#
#     2019년  2020년  2021년         최근증가율
# 6     218    223    219  65600.000000
# 22    339    433    556  50925.000000
# 9    1078    656    470  38525.000000
# 12   1057    288    471  29407.142857
# 2     155    361    403  15193.750000

# %%
CCTV_Seoul = CCTV_Seoul.drop(['2012년','2013년','2014년','2015년','2016년','2017년','2018년'], axis=1)

# %%
CCTV_Seoul = CCTV_Seoul.rename(columns={CCTV_Seoul.columns[0]:'구별'})

# %%
CCTV_Seoul.head()
# Out:
#       구별    총계  2012년 이전  2019년  2020년  2021년         최근증가율
# 6   동대문구  2628         4    218    223    219  65600.000000
# 22   서초구  4082         8    339    433    556  50925.000000
# 9    강북구  3090         8   1078    656    470  38525.000000
# 12   은평구  4131        14   1057    288    471  29407.142857
# 2    중 구  2447        16    155    361    403  15193.750000

# %%
pop_Seoul.head()
# Out:
#     구별     인구수     한국인    외국인    고령자     외국인비율      고령자비율
# 1  종로구  153684  144275   9409  28064  6.122303  18.260847
# 2   중구  131450  122173   9277  24742  7.057436  18.822366
# 3  용산구  236518  222169  14349  39461  6.066769  16.684142
# 4  성동구  291609  285073   6536  46896  2.241357  16.081808
# 5  광진구  353110  340707  12403  52604  3.512503  14.897341

# %%
data_result = pd.merge(CCTV_Seoul, pop_Seoul, on='구별')
data_result.head()
# Out:
#      구별    총계  2012년 이전  2019년  2020년  2021년         최근증가율     인구수     한국인  \
# 0  동대문구  2628         4    218    223    219  65600.000000  352592  337982
# 1   서초구  4082         8    339    433    556  50925.000000  413677  409823
# 2   강북구  3090         8   1078    656    470  38525.000000  300824  297384
# 3   은평구  4131        14   1057    288    471  29407.142857  476013  472259
# 4   마포구  2496        23    494    299    108  10752.173913  378629  368331
#
#      외국인    고령자     외국인비율      고령자비율
# 0  14610  62963  4.143599  17.857183
# 1   3854  61404  0.931645  14.843465
# 2   3440  64961  1.143526  21.594354
# 3   3754  88418  0.788634  18.574703
# 4  10298  55168  2.719813  14.570463

# %%
del data_result['2012년 이전']
del data_result['2019년']
del data_result['2020년']
del data_result['2021년']
data_result.head()
# Out:
#      구별    총계         최근증가율     인구수     한국인    외국인    고령자     외국인비율      고령자비율
# 0  동대문구  2628  65600.000000  352592  337982  14610  62963  4.143599  17.857183
# 1   서초구  4082  50925.000000  413677  409823   3854  61404  0.931645  14.843465
# 2   강북구  3090  38525.000000  300824  297384   3440  64961  1.143526  21.594354
# 3   은평구  4131  29407.142857  476013  472259   3754  88418  0.788634  18.574703
# 4   마포구  2496  10752.173913  378629  368331  10298  55168  2.719813  14.570463

# %%
data_result.set_index('구별', inplace=True)
data_result.head()
# Out:
#         총계         최근증가율     인구수     한국인    외국인    고령자     외국인비율      고령자비율
# 구별
# 동대문구  2628  65600.000000  352592  337982  14610  62963  4.143599  17.857183
# 서초구   4082  50925.000000  413677  409823   3854  61404  0.931645  14.843465
# 강북구   3090  38525.000000  300824  297384   3440  64961  1.143526  21.594354
# 은평구   4131  29407.142857  476013  472259   3754  88418  0.788634  18.574703
# 마포구   2496  10752.173913  378629  368331  10298  55168  2.719813  14.570463

# %%
# CCTV 개수가 증가하는데, 대체 어떤 기준으로 증가하고 있는가?
np.corrcoef(data_result['고령자비율'], data_result['총계'])
# 고령자가 많은 곳의 CCTV 개수와 음의 상관관계
# Out:
# array([[ 1.        , -0.31104534],
#        [-0.31104534,  1.        ]])

# %%
np.corrcoef(data_result['외국인비율'], data_result['총계'])
# Out:
# array([[ 1.       , -0.1535195],
#        [-0.1535195,  1.       ]])

# %%
np.corrcoef(data_result['인구수'], data_result['총계'])
# 인구수 0.3의 상관관계
# Out:
# array([[1.        , 0.44356954],
#        [0.44356954, 1.        ]])

# %%
data_result.sort_values(by='총계', ascending=False).head(5)
# Out:
#        총계         최근증가율     인구수     한국인    외국인    고령자     외국인비율      고령자비율
# 구별
# 강남구  6871   9857.971014  537338  532577   4761  79575  0.886034  14.809115
# 관악구  5149   1070.227273  500336  486375  13961  80686  2.790325  16.126363
# 구로구  4608    440.845070  419984  396017  23967  73864  5.706646  17.587337
# 성북구  4602   5581.481481  442680  433150   9530  75719  2.152797  17.104681
# 은평구  4131  29407.142857  476013  472259   3754  88418  0.788634  18.574703

# %%
data_result.sort_values(by='인구수', ascending=False).head(5)
# Out:
#        총계         최근증가율     인구수     한국인    외국인    고령자     외국인비율      고령자비율
# 구별
# 송파구  2897   7142.500000  668261  662607   5654  99854  0.846077  14.942365
# 강서구  2744   4981.481481  578426  573046   5380  93924  0.930110  16.237859
# 강남구  6871   9857.971014  537338  532577   4761  79575  0.886034  14.809115
# 관악구  5149   1070.227273  500336  486375  13961  80686  2.790325  16.126363
# 은평구  4131  29407.142857  476013  472259   3754  88418  0.788634  18.574703

# %%
import matplotlib.pyplot as plt

# %%
plt.rc('font', family='NanumGothic')

# %%
data_result.head()
# Out:
#         총계         최근증가율     인구수     한국인    외국인    고령자     외국인비율      고령자비율
# 구별
# 동대문구  2628  65600.000000  352592  337982  14610  62963  4.143599  17.857183
# 서초구   4082  50925.000000  413677  409823   3854  61404  0.931645  14.843465
# 강북구   3090  38525.000000  300824  297384   3440  64961  1.143526  21.594354
# 은평구   4131  29407.142857  476013  472259   3754  88418  0.788634  18.574703
# 마포구   2496  10752.173913  378629  368331  10298  55168  2.719813  14.570463

# %%
# 그래프를 노트북 안에 그리기 위해 설정
# %matplotlib inline

# 필요한 패키지와 라이브러리를 가져옴
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# %%
print ('버전: ', mpl.__version__)
print ('설치 위치: ', mpl.__file__)
print ('설정 위치: ', mpl.get_configdir())
print ('캐시 위치: ', mpl.get_cachedir())
# Out:
# 버전:  3.5.1
# 설치 위치:  C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\__init__.py
# 설정 위치:  C:\Users\광운MOOC센터\.matplotlib
# 캐시 위치:  C:\Users\광운MOOC센터\.matplotlib

# %%
font_list = fm.findSystemFonts(fontpaths=None, fontext='ttf')

# ttf 폰트 전체갯수
print(len(font_list))
# Out:
# 401

# %%
font_list[:10]
# Out:
# ['C:\\Windows\\Fonts\\ERASBD.TTF',
#  'C:\\Windows\\Fonts\\seguiemj.ttf',
#  'C:\\Windows\\Fonts\\COPRGTB.TTF',
#  'C:\\Windows\\Fonts\\GARAIT.TTF',
#  'C:\\Windows\\Fonts\\STKAITI.TTF',
#  'C:\\Windows\\Fonts\\Phetsarath OT.ttf',
#  'C:\\Windows\\Fonts\\H2GTRE.TTF',
#  'C:\\Windows\\Fonts\\OUTLOOK.TTF',
#  'C:\\Windows\\Fonts\\javatext.ttf',
#  'C:\\Windows\\Fonts\\seguisb.ttf']

# %%
[(f.name, f.fname) for f in fm.fontManager.ttflist if 'Nanum' in f.name]
# Out:
# [('NanumGothic', 'C:\\Windows\\Fonts\\\x7f\x7f\x7f\x7fEXTRABOLD.TTF'),
#  ('NanumGothic', 'C:\\Windows\\Fonts\\\x7f\x7f\x7f\x7f.TTF'),
#  ('NanumGothic', 'C:\\Windows\\Fonts\\\x7f\x7f\x7f\x7fBOLD.TTF')]

# %%
plt.figure()
data_result['총계'].plot(kind='barh', grid=True, figsize=(8,8))
plt.show()

# %%
data_result['총계'].sort_values().plot(kind='barh', grid=True, figsize=(10,10))
# plt.show()
# Out:
# <AxesSubplot:ylabel='구별'>

# %%
data_result['CCTV비율'] = data_result['총계']/data_result['인구수'] * 100

data_result['CCTV비율'].sort_values().plot(kind='barh', grid=True, figsize=(10,10))

plt.show()

# %%
plt.figure(figsize=(6,6))
plt.scatter(data_result['인구수'], data_result['총계'], s=50)
plt.xlabel('인구수')
plt.ylabel('CCTV')
plt.grid()
plt.show()

# %%
fp1 = np.polyfit(data_result['인구수'], data_result['총계'], 1)

f1 = np.poly1d(fp1)
fx = np.linspace(100000, 700000, 100)

data_result['오차'] = np.abs(data_result['총계'] - f1(data_result['인구수']))

df_sort = data_result.sort_values(by='오차', ascending=False)
df_sort.head()
# Out:
#        총계        최근증가율     인구수     한국인    외국인    고령자     외국인비율      고령자비율  \
# 구별
# 강남구  6871  9857.971014  537338  532577   4761  79575  0.886034  14.809115
# 송파구  2897  7142.500000  668261  662607   5654  99854  0.846077  14.942365
# 강서구  2744  4981.481481  578426  573046   5380  93924  0.930110  16.237859
# 관악구  5149  1070.227273  500336  486375  13961  80686  2.790325  16.126363
# 도봉구  1930  1407.812500  318100  316098   2002  65122  0.629362  20.472179
#
#        CCTV비율           오차
# 구별
# 강남구  1.278711  2787.767900
# 송파구  0.433513  1784.869460
# 강서구  0.474391  1527.104452
# 관악구  1.029108  1234.957267
# 도봉구  0.606727  1150.779838

# %%
plt.figure(figsize = (14,10))
plt.scatter(data_result['인구수'], data_result['총계'],
           c = data_result['오차'], s = 50)
plt.plot(fx, f1(fx), ls = 'dashed', lw=3, color='g') #ls : line style

for n in range(10):
    plt.text(df_sort['인구수'][n]*1.02, df_sort['총계'][n]*0.98,
            df_sort.index[n], fontsize=15)
    
plt.xlabel('인구수')
plt.ylabel('인구당비율')
plt.colorbar()
plt.grid()
plt.show()
